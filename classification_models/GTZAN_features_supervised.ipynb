# %% [markdown]
# ## Classification Models Run on GTZAN features
#
# These models were not expected to do as well on the GTZAN features as librosa and VGGish, but provide a great comparison on results. To use this file, change the directory to your "Data" folder from the GTZAN dataset.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sklearn
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from sklearn import metrics 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from keras.optimizers import SGD
# Imports and load dataset
music_data = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Data/features_30_sec.csv')

# %%
import librosa.display
import librosa
import matplotlib.pyplot as plt

# Load audio file and display spectrogram with librosa

audio_path = 'C:/Users/youlu/Jupyter Labs/blues.wav'
x, sr = librosa.load(audio_path)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
plt.title("Spectrogram of Blues Song")
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:50, in show(close, block)
#      47 # only call close('all') if any to close
#      48 # close triggers gc.collect, which can be slow
#      49 if close and Gcf.get_all_fig_managers():
# ---> 50     matplotlib.pyplot.close('all')
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:222, in caching_module_getattr.<locals>.__getattr__(name)
#     220 if name in props:
#     221     return props[name].__get__(instance)
# --> 222 raise AttributeError(
#     223     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from xgboost import XGBClassifier
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder
# Getting data and creating proper feature dataset
df = music_data
df = df.set_index(df['filename'])
df = df.drop(['filename'], axis = 1)
df = df.drop(['length','rms_var',
              'zero_crossing_rate_var','harmony_mean',
              'perceptr_mean'], axis=1)
y = df['label']
df = df.drop(['label'], axis=1)
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)
# print(scaled_df)
features = scaled_df
# one-hot encoding of labels
cols = ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(
features, y, test_size=.25, random_state=42)

# %%
# Now we try a variety of models below, using gridsearch for hyperparameter tuning

# XGBoost
params = {'n_estimators': [200, 400, 500, 600, 800, 900, 1200], 'max_depth': [3, 4, 5]}
model = XGBClassifier(objective = 'softmax', num_class = 10, random_state=42)
# Grid Search
model_cv = GridSearchCV(estimator=model, param_grid=params, n_jobs=-1, cv=3)
model_cv.fit(X_train, y_train)
best_params = model_cv.best_params_
print("The best parameters are:", best_params)
#clf = XGBClassifier(colsample_bytree = 0.6, gamma= 0.5, max_depth= 3, min_child_weight= 1, subsample= 0.6, objective = 'softmax', num_class = 10, random_state=42)
clf = XGBClassifier(**best_params, objective = 'softmax', num_class = 10, random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Accuracy of the classifier is:", accuracy_score(y_test,y_pred))
acc_train = clf.score(X_train, y_train)
print("Accuracy on train = %0.4f " % acc_train)
acc_test = clf.score(X_test, y_test)
print("Accuracy on test = %0.4f " % acc_test)
# Out:
# The best parameters are: {'max_depth': 5, 'n_estimators': 400}
# Accuracy of the classifier is: 0.668
# Accuracy on train = 0.9987
# Accuracy on test = 0.6680

# %%
m = [10, 20, 40, 80, 160, 320, 400]
scores = []
scores2 = []
for n in m:
    model_xgb = XGBClassifier(n_estimators=n, learning_rate=.01, max_depth = 3)
    model_xgb.fit(X_train, y_train)
    scores.append(model_xgb.score(X_train, y_train))
    scores2.append(model_xgb.score(X_test, y_test))
plt.plot(m, scores, 'o-', label='Train Accuracy', color = 'g')
plt.plot(m, scores2, 'o-', label='Test Accuracy', color = 'r')
plt.legend()
plt.show()

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

params = {'min_samples_leaf': np.arange(1, 10), 'max_depth': np.arange(1,10)}
model = DecisionTreeClassifier(random_state = 42)
model_cv = GridSearchCV(estimator=model, param_grid=params, n_jobs=-1, cv=3)
model_cv.fit(X_train, y_train)
best_params = model_cv.best_params_
print("The best parameters are:", best_params)
clf = DecisionTreeClassifier(**best_params, criterion = 'log_loss', random_state = 42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
pred = clf.predict_proba(X_test)
acc_train = clf.score(X_train, y_train)
print("Accuracy on train = %0.4f " % acc_train)
acc_test = clf.score(X_test, y_test)
print("Accuracy on test = %0.4f " % acc_test)
# Out:
# The best parameters are: {'max_depth': 9, 'min_samples_leaf': 2}
# Accuracy on train = 0.9200
# Accuracy on test = 0.4360

# %%
from sklearn.ensemble import RandomForestClassifier
# Random Forest
params = { 'n_estimators': [200, 400, 600, 800],'max_features': ['auto', 'sqrt', 'log2'],'max_depth' : [4,5,6,7,8]}
#model = RandomForestClassifier(random_state=42, criterion = 'log_loss')
#model_cv = GridSearchCV(estimator=model, param_grid=params, n_jobs=-1, cv=3)
#model_cv.fit(X_train, y_train)
#best_params = model_cv.best_params_
#print("The best parameters are:", best_params)
clf = RandomForestClassifier(max_features= 'log2', n_estimators = 800, max_depth = 5, criterion = 'log_loss', random_state = 42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
pred = clf.predict_proba(X_test)
acc_train = clf.score(X_train, y_train)
print("Accuracy on train = %0.4f " % acc_train)
acc_test = clf.score(X_test, y_test)
print("Accuracy on test = %0.4f " % acc_test)
# Out:
# The best parameters are: {'max_depth': 7, 'max_features': 'log2', 'n_estimators': 800}
# Accuracy on train = 0.9973
# Accuracy on test = 0.6600

# %%
m = [10, 20, 40, 80, 160, 320, 400, 600, 800, 1000, 1200]
scores = []
scores2 = []
for n in m:
    clf = RandomForestClassifier(max_features= 'log2', n_estimators = n, max_depth = 6, criterion = 'log_loss', random_state = 42)
    clf.fit(X_train, y_train)
    scores.append(clf.score(X_train, y_train))
    scores2.append(clf.score(X_test, y_test))
plt.plot(m, scores, 'o-', label='Train Accuracy', color = 'g')
plt.plot(m, scores2, 'o-', label='Test Accuracy', color = 'r')
plt.legend()
plt.show()

# %%
import catboost as cb
# Cat Boost
clf = cb.CatBoostClassifier(verbose=0, eval_metric='Accuracy', loss_function='MultiClass')
clf.fit(X_train, y_train)
preds = clf.predict(X_test)
print(accuracy_score(y_test, preds))
# Out:
# 0.696

# %%
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from keras.utils.vis_utils import plot_model
#MLP
# Architecture from https://www.geeksforgeeks.org/music-genre-classifier-using-machine-learning/#
model = Sequential()
  
model.add(Flatten(input_shape=(53,)))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))

plot_model(model,  show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import tensorflow.keras as keras
#       2 from tensorflow.keras import Sequential
#       3 from tensorflow.keras.layers import *
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Compile and fit the model
model.compile(optimizer='adam',
             loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
  
hist = model.fit(X_train, y_train,
                 validation_data = (X_test,y_test),
                 epochs = 100,
                 batch_size = 32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 2s 11ms/step - loss: 1.8404 - accuracy: 0.3653 - val_loss: 2.2491 - val_accuracy: 0.0880
# Epoch 2/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.1917 - accuracy: 0.5747 - val_loss: 2.1831 - val_accuracy: 0.1440
# Epoch 3/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9891 - accuracy: 0.6560 - val_loss: 2.1083 - val_accuracy: 0.1440
# Epoch 4/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8755 - accuracy: 0.7067 - val_loss: 2.0200 - val_accuracy: 0.2280
# Epoch 5/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7939 - accuracy: 0.7280 - val_loss: 1.9114 - val_accuracy: 0.3880
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7274 - accuracy: 0.7520 - val_loss: 1.8092 - val_accuracy: 0.4560
# Epoch 7/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6633 - accuracy: 0.7640 - val_loss: 1.7348 - val_accuracy: 0.5200
# Epoch 8/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6085 - accuracy: 0.7893 - val_loss: 1.6410 - val_accuracy: 0.5680
# Epoch 9/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6076 - accuracy: 0.7987 - val_loss: 1.5320 - val_accuracy: 0.6240
# Epoch 10/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5506 - accuracy: 0.8147 - val_loss: 1.4058 - val_accuracy: 0.6760
# Epoch 11/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5353 - accuracy: 0.8227 - val_loss: 1.3592 - val_accuracy: 0.6720
# Epoch 12/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4769 - accuracy: 0.8440 - val_loss: 1.2380 - val_accuracy: 0.6800
# Epoch 13/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.8253 - val_loss: 1.1983 - val_accuracy: 0.6640
# Epoch 14/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4593 - accuracy: 0.8493 - val_loss: 1.1270 - val_accuracy: 0.6720
# Epoch 15/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4739 - accuracy: 0.8253 - val_loss: 1.0517 - val_accuracy: 0.7000
# Epoch 16/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.8640 - val_loss: 0.9969 - val_accuracy: 0.6880
# Epoch 17/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3959 - accuracy: 0.8693 - val_loss: 0.9598 - val_accuracy: 0.7200
# Epoch 18/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3654 - accuracy: 0.8733 - val_loss: 0.9349 - val_accuracy: 0.7160
# Epoch 19/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3972 - accuracy: 0.8547 - val_loss: 0.9171 - val_accuracy: 0.6880
# Epoch 20/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3578 - accuracy: 0.8760 - val_loss: 0.8807 - val_accuracy: 0.7200
# Epoch 21/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3351 - accuracy: 0.8880 - val_loss: 0.8879 - val_accuracy: 0.7200
# Epoch 22/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3234 - accuracy: 0.9000 - val_loss: 0.9550 - val_accuracy: 0.6760
# Epoch 23/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2719 - accuracy: 0.9107 - val_loss: 0.8940 - val_accuracy: 0.7040
# Epoch 24/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2999 - accuracy: 0.9093 - val_loss: 0.9704 - val_accuracy: 0.6920
# Epoch 25/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2934 - accuracy: 0.9000 - val_loss: 0.8392 - val_accuracy: 0.7280
# Epoch 26/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2914 - accuracy: 0.8973 - val_loss: 0.8944 - val_accuracy: 0.7240
# Epoch 27/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2629 - accuracy: 0.9133 - val_loss: 0.8691 - val_accuracy: 0.7280
# Epoch 28/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2562 - accuracy: 0.9253 - val_loss: 0.9346 - val_accuracy: 0.7200
# Epoch 29/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2618 - accuracy: 0.9200 - val_loss: 0.8820 - val_accuracy: 0.7240
# Epoch 30/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2435 - accuracy: 0.9213 - val_loss: 0.9321 - val_accuracy: 0.7160
# Epoch 31/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2278 - accuracy: 0.9320 - val_loss: 0.9927 - val_accuracy: 0.7320
# Epoch 32/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2292 - accuracy: 0.9120 - val_loss: 0.9692 - val_accuracy: 0.6920
# Epoch 33/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2273 - accuracy: 0.9267 - val_loss: 0.9922 - val_accuracy: 0.7280
# Epoch 34/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2453 - accuracy: 0.9147 - val_loss: 1.0017 - val_accuracy: 0.7240
# Epoch 35/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2255 - accuracy: 0.9240 - val_loss: 1.1013 - val_accuracy: 0.7000
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2102 - accuracy: 0.9240 - val_loss: 1.1818 - val_accuracy: 0.7120
# Epoch 37/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1995 - accuracy: 0.9320 - val_loss: 1.0453 - val_accuracy: 0.7080
# Epoch 38/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2007 - accuracy: 0.9413 - val_loss: 1.0876 - val_accuracy: 0.6920
# Epoch 39/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1885 - accuracy: 0.9320 - val_loss: 1.0699 - val_accuracy: 0.7040
# Epoch 40/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1817 - accuracy: 0.9440 - val_loss: 1.1565 - val_accuracy: 0.6920
# Epoch 41/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1670 - accuracy: 0.9493 - val_loss: 1.0141 - val_accuracy: 0.6880
# Epoch 42/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1715 - accuracy: 0.9373 - val_loss: 1.0196 - val_accuracy: 0.7200
# Epoch 43/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1750 - accuracy: 0.9400 - val_loss: 0.9837 - val_accuracy: 0.7400
# Epoch 44/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1822 - accuracy: 0.9333 - val_loss: 1.1995 - val_accuracy: 0.6840
# Epoch 45/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1909 - accuracy: 0.9387 - val_loss: 1.1412 - val_accuracy: 0.7240
# Epoch 46/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9693 - val_loss: 1.0165 - val_accuracy: 0.7560
# Epoch 47/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1517 - accuracy: 0.9453 - val_loss: 1.0440 - val_accuracy: 0.7320
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1424 - accuracy: 0.9547 - val_loss: 1.1498 - val_accuracy: 0.7160
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1849 - accuracy: 0.9333 - val_loss: 1.0180 - val_accuracy: 0.7240
# Epoch 50/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1422 - accuracy: 0.9520 - val_loss: 1.2386 - val_accuracy: 0.7000
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1443 - accuracy: 0.9587 - val_loss: 1.2693 - val_accuracy: 0.6960
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1413 - accuracy: 0.9547 - val_loss: 1.0891 - val_accuracy: 0.7360
# Epoch 53/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1185 - accuracy: 0.9640 - val_loss: 1.1807 - val_accuracy: 0.6960
# Epoch 54/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1495 - accuracy: 0.9467 - val_loss: 1.1550 - val_accuracy: 0.6880
# Epoch 55/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1089 - accuracy: 0.9707 - val_loss: 1.0972 - val_accuracy: 0.7160
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1443 - accuracy: 0.9520 - val_loss: 1.3210 - val_accuracy: 0.7080
# Epoch 57/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1208 - accuracy: 0.9640 - val_loss: 1.2483 - val_accuracy: 0.6920
# Epoch 58/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9733 - val_loss: 1.1189 - val_accuracy: 0.7080
# Epoch 59/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1045 - accuracy: 0.9693 - val_loss: 1.0794 - val_accuracy: 0.7400
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 0.9653 - val_loss: 0.9927 - val_accuracy: 0.7400
# Epoch 61/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9787 - val_loss: 1.1111 - val_accuracy: 0.7240
# Epoch 62/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1262 - accuracy: 0.9560 - val_loss: 1.1161 - val_accuracy: 0.7320
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9760 - val_loss: 1.2015 - val_accuracy: 0.7240
# Epoch 64/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0933 - accuracy: 0.9813 - val_loss: 1.3981 - val_accuracy: 0.7200
# Epoch 65/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1117 - accuracy: 0.9627 - val_loss: 1.3782 - val_accuracy: 0.6800
# Epoch 66/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 0.9693 - val_loss: 1.0295 - val_accuracy: 0.7520
# Epoch 67/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0817 - accuracy: 0.9827 - val_loss: 1.3055 - val_accuracy: 0.7160
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0970 - accuracy: 0.9747 - val_loss: 1.0712 - val_accuracy: 0.7400
# Epoch 69/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1210 - accuracy: 0.9573 - val_loss: 1.2626 - val_accuracy: 0.7120
# Epoch 70/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0988 - accuracy: 0.9733 - val_loss: 1.6198 - val_accuracy: 0.6480
# Epoch 71/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9733 - val_loss: 1.2178 - val_accuracy: 0.7120
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0825 - accuracy: 0.9760 - val_loss: 1.1085 - val_accuracy: 0.7680
# Epoch 73/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9720 - val_loss: 1.0992 - val_accuracy: 0.7440
# Epoch 74/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1111 - accuracy: 0.9640 - val_loss: 1.1383 - val_accuracy: 0.7160
# Epoch 75/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 0.9733 - val_loss: 1.3462 - val_accuracy: 0.7120
# Epoch 76/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0940 - accuracy: 0.9707 - val_loss: 1.3123 - val_accuracy: 0.7120
# Epoch 77/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1168 - accuracy: 0.9653 - val_loss: 1.2137 - val_accuracy: 0.6840
# Epoch 78/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.9733 - val_loss: 1.2354 - val_accuracy: 0.7400
# Epoch 79/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1240 - accuracy: 0.9640 - val_loss: 1.1777 - val_accuracy: 0.7200
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9693 - val_loss: 1.5509 - val_accuracy: 0.6960
# Epoch 81/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0846 - accuracy: 0.9720 - val_loss: 1.3415 - val_accuracy: 0.7160
# Epoch 82/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1031 - accuracy: 0.9613 - val_loss: 1.2173 - val_accuracy: 0.7360
# Epoch 83/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1110 - accuracy: 0.9653 - val_loss: 1.2782 - val_accuracy: 0.7120
# Epoch 84/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9707 - val_loss: 1.2248 - val_accuracy: 0.7000
# Epoch 85/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0806 - accuracy: 0.9800 - val_loss: 1.2824 - val_accuracy: 0.7320
# Epoch 86/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0882 - accuracy: 0.9707 - val_loss: 1.2878 - val_accuracy: 0.7160
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9827 - val_loss: 1.2224 - val_accuracy: 0.7360
# Epoch 88/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0650 - accuracy: 0.9827 - val_loss: 1.1802 - val_accuracy: 0.6960
# Epoch 89/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.9787 - val_loss: 1.2836 - val_accuracy: 0.7080
# Epoch 90/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9760 - val_loss: 1.2780 - val_accuracy: 0.7200
# Epoch 91/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9800 - val_loss: 1.3103 - val_accuracy: 0.7240
# Epoch 92/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9867 - val_loss: 1.2679 - val_accuracy: 0.7160
# Epoch 93/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0662 - accuracy: 0.9840 - val_loss: 1.3299 - val_accuracy: 0.7160
# Epoch 94/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0671 - accuracy: 0.9813 - val_loss: 1.6486 - val_accuracy: 0.6720
# Epoch 95/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9800 - val_loss: 1.4268 - val_accuracy: 0.6920
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9787 - val_loss: 1.3998 - val_accuracy: 0.7160
# Epoch 97/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0950 - accuracy: 0.9653 - val_loss: 1.4516 - val_accuracy: 0.7160
# Epoch 98/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0667 - accuracy: 0.9787 - val_loss: 1.4818 - val_accuracy: 0.7280
# Epoch 99/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0774 - accuracy: 0.9733 - val_loss: 1.4666 - val_accuracy: 0.7240
# Epoch 100/100
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0738 - accuracy: 0.9787 - val_loss: 1.6714 - val_accuracy: 0.6720

# %%
# Plot the accuracy of the model over epochs

fig, axs = plt.subplots(2,figsize=(10,10))
  
# accuracy 
axs[0].plot(hist.history["accuracy"], label="train")
axs[0].plot(hist.history["val_accuracy"], label="test")    
axs[0].set_ylabel("Accuracy")
axs[0].legend()
axs[0].set_title("Accuracy")
      
# Error 
axs[1].plot(hist.history["loss"], label="train")
axs[1].plot(hist.history["val_loss"], label="test")    
axs[1].set_ylabel("Error")
axs[1].legend()
axs[1].set_title("Error")
      
plt.show()

# %%
# K Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
m = np.arange(4, 61, 2)
scores = []
for n in m:
  knn = KNeighborsClassifier(n_neighbors=n)
  cv_scores = cross_val_score(knn, X_train, y_train, cv=10)
  scores.append(np.mean(cv_scores))
plt.plot(m, scores)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression(multi_class='ovr', solver='liblinear')
lm.fit(X_train, y_train)
y_pred = lm.predict(X_test)
pred = lm.predict_proba(X_test)
acc_train = lm.score(X_train, y_train)
print("Accuracy on train = %0.4f " % acc_train)
acc_test = lm.score(X_test, y_test)
print("Accuracy on test = %0.4f " % acc_test)
# Out:
# Accuracy on train = 0.7253
# Accuracy on test = 0.5440

# %%
# Conclusion: GTZAN features do not give very good accuracy on any model - MLP or Rand Forest best
